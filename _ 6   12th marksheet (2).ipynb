# %%
m1=(" ")
m2=("\t\t")
m3=("\t\t")
m4=("\t\t\t")
m5=("\t\t\t\t")
name=input("Enter candidate name")
fname=input("Enter father's name")
mname=input("Enter mother's name")
classs=input("Enter classs ")
roll_no=int(input("Enter roll_no"))
center=input("Enter center")
distric=input("Enter distric")
student=input("regular/privite")
date=input("Enter date")
subject1=int(input("Enter Hindi(comp.) marks"))
subject2=int(input("Enter English(comp.) marks"))
subject3=int(input("Enter Pol.science marks"))
subject4=int(input("Enter sanskrit marks"))
subject5=int(input("Enter geography marks"))
marks=(subject1+subject2+subject3+subject4+subject5)
percentage=((subject1+subject2+subject3+subject4+subject5)/500)*100
print("----------------------------------------------------------------------------\n")
print(m2,"BOARD OF SECONDARY EDUCATION, RAJASTHAN ")
print("\n",m2,"CARTIFICATE WITH MARK-SHEET")
print(m2,"senior secondary examination - 2024")
print("=============================================================================")
print(m1,"roll_number",m1,"center",m2,"distric",m2,"student")
print(m1,roll_no,m2,center,m3,distric,m4,student)
print("==============================================================================")
print("candidate name :",name)
print("father'name:",fname )
print("mother's name:",mname)
print("class :",classs)
print("-------------------------------------------------------------------------------")
print("comp/optional subject",m1,"max.marks",m1,"min.pass marks",m1,"marks obtained")
print("Hindi(comp.)",m2,"80",m2,"33",m2,subject1)
print("English(comp.)",m2,"80",m2,"33",m2,subject2)
print("pol.seience",m2,"80",m2,"33",m2,subject3)
print("sanskrit",m2,"80",m2,"33",m2,subject4)
print("geography",m2,"80",m2,"33",m2,subject5)
print("__________________________________________________________________________________")
print("Total max. marks",m3,"Total marks obtained")
print("500",m5,percentage)
if percentage>=90 and percentage<=100:
    print("Grade : A+","   ","PASS")
elif percentage>=80 and percentage<90:
    print("Grade : A","   ","PASS")
elif percentage>=70 and percentage<80:
    print("Grade : B+","   ","PASS")
elif percentage>=60 and percentage<70:
    print("Grade : B","   ","PASS")
elif percentage>=40 and percentage<60:
    print("Grade : c","   ","FAIL")
elif percentage>=0 and percentage<40:
    print("Grade : D","   ","FAIL ND NEED IMPROVEMENT")
else:
    print("NOT A VALID MARKS")
print("*********************************************************************************************************************\n")
print("DATE:",date)
# Out:
# Enter candidate name lucky kumawat
# Enter father's name makhan lal kumawat
# Enter mother's name sunita devi
# Enter classs  12
# Enter roll_no 3648273
# Enter center samod
# Enter distric jaipur
# regular/privite regular
# Enter date 12-03-2023
# Enter Hindi(comp.) marks 50
# Enter English(comp.) marks 80
# Enter Pol.science marks 70
# Enter sanskrit marks 60
# Enter geography marks 67
# ----------------------------------------------------------------------------
#
# 		 BOARD OF SECONDARY EDUCATION, RAJASTHAN
#
#  		 CARTIFICATE WITH MARK-SHEET
# 		 senior secondary examination - 2024
# ...
#   roll_number   center 		 distric 		 student
#   3648273 		 samod 		 jaipur 			 regular
# ...
# candidate name : lucky kumawat
# father'name: makhan lal kumawat
# mother's name: sunita devi
# class : 12
# -------------------------------------------------------------------------------
# comp/optional subject   max.marks   min.pass marks   marks obtained
# Hindi(comp.) 		 80 		 33 		 50
# ...
